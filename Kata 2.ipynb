# %% [markdown]
# # Kata 2
# ## Ejercicio - Crear un Paquete
# ### Entorno Virtual
#
# Para crear un entorno virtual se debe abrir el terminal y escribir la dirección de donde se va a guardar el Proyecto. En mi caso es `cd Documents/LaunchX`.
# ![Captura%201.png](attachment:Captura%201.png)

# %% [markdown]
# Posteriormente se ejecuta en el terminal `python -m venv env` para tener un directorio `env`creado en el terminal. Luego ejecutar el comando para activar el entorno virtual: `source env/bin/activate`

# %% [markdown]
# ![Captura%203.png](attachment:Captura%203.png)

# %% [markdown]
# Es importante corroborar que paquetes existen en la biblioteca instalada con `pip freeze` En este caso no saldrá ninguno porque aun no lo instalamos
# ![Captura%204.png](attachment:Captura%204.png)

# %% [markdown]
# Para instalar una biblioteca usamos el comando `pip install` seguido de `python-dateutil` y al ejecutar el comando se mostrara la siguiente salida
# ![Captura%205.png](attachment:Captura%205.png)

# %% [markdown]
# Volvemos a ejecutar `pip freeze` y se observará la siguiente lista correspondiente al paquete
# ![Captura%206.png](attachment:Captura%206.png)

# %% [markdown]
# Finalmente ejecutamos el comando `desactivate` para trabajar con otros proyectos, de tal forma que en la terminal ya no se observara `(env)` y se mirará como al inicio.
# ![Captura%207.png](attachment:Captura%207.png)
